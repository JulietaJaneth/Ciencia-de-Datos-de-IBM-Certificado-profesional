# %% [markdown]
# # Proyecto final
#
#
# ### Autora: Chávez Bartolo Julieta Janeth
#
# Este notebook se utilizará principalmente para el proyecto final del curso *certificado pr*

# %%
import numpy as np
import pandas as pd
